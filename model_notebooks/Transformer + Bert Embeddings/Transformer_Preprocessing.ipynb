# %% [markdown]
# ## Load Data

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import pandas as pd
import re

# %%
# !pip install pyspellchecker
# !pip install contextualSpellCheck
# To assess different spell checkers for our needs

# %%
# code taken from https://www.cl.cam.ac.uk/research/nl/bea2019st/data/corr_from_m2.py
def m2_to_df(m2, id):
    # Do not apply edits with these error types
    skip = {"noop", "UNK", "Um"}
    ori_sentences = []
    corrected_sentences = []
    for sent in m2:
        sent = sent.split("\n")
        ori_sent = sent[0].split()[1:] # Ignore "S "
        cor_sent = ori_sent.copy()
        edits = sent[1:]
        offset = 0
        for edit in edits:
            edit = edit.split("|||")
            if edit[1] in skip: continue # Ignore certain edits
            coder = int(edit[-1])
            if coder != id: continue # Ignore other coders
            span = edit[0].split()[1:] # Ignore "A "
            start = int(span[0])
            end = int(span[1])
            cor = edit[2].split()
            cor_sent[start+offset:end+offset] = cor
            offset = offset-(end-start)+len(cor)
        ori_sentences.append(" ".join(ori_sent))
        corrected_sentences.append(" ".join(cor_sent))
    df = pd.DataFrame(list(zip(ori_sentences, corrected_sentences)),columns =['original', 'corrected'])
    return df

# %%
# Change path here
with open('/content/drive/MyDrive/CS4248NLP/wi+locness/m2/ABC.train.gold.bea19.m2') as f:
    m2_train = f.read().strip().split("\n\n")
    train_df = m2_to_df(m2_train, 0)

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None
print("First sentence")
print(train_df.loc[0]["original"])
print(train_df.loc[0]["corrected"])
# Out:
# First sentence
# My town is a medium size city with eighty thousand inhabitants .
# My town is a medium - sized city with eighty thousand inhabitants .

# %%
train_df.shape
# Out:
# (34308, 2)

# %%
train_df.head()
# Out:
#                                                                                              original  \
# 0                                    My town is a medium size city with eighty thousand inhabitants .
# 1                                      It has a high density population because its small territory .
# 2                  Despite of it is an industrial city , there are many shops and department stores .
# 3  I recommend visiting the artificial lake in the certer of the city which is surrounded by a park .
# 4                Pasteries are very common and most of them offer the special dessert from the city .
#
#                                                                                             corrected
# 0                                 My town is a medium - sized city with eighty thousand inhabitants .
# 1                                 It has a high - density population because of its small territory .
# 2                    Although it is an industrial city , there are many shops and department stores .
# 3  I recommend visiting the artificial lake in the center of the city which is surrounded by a park .
# 4                  Pasteries are very common and most of them offer the special dessert of the city .

# %%
train_df['correct_char_count'] = train_df['corrected'].astype('str').apply(lambda x:len(x))
train_df['original_char_count'] = train_df['original'].astype('str').apply(lambda x:len(x))

# %%
train_df['correct_word_count'] = train_df['corrected'].astype('str').apply(lambda x:len(x.split()))
train_df['original_word_count'] = train_df['original'].astype('str').apply(lambda x:len(x.split()))

# %%
train_df.sample(5)
# Out:
#                                                                                                                          original  \
# 21674                                                                     I completely agree with you , maybe each word you say .
# 22820  So , you will be able to live and watch all this amazing exotic flowers , to hear Colombian music and see typical dances .
# 33629                                            Adults usually attend language courses , or use a variety of on - line courses .
# 16994                                                                     The building has two changing rooms for men and women .
# 26694                                                         The amount of talking done by the students was more that pleasing .
#
#                                                                                                                                    corrected  \
# 21674                                                                                I completely agree with you , maybe each word you say .
# 22820  So , you will be able to experience and watch all these amazing exotic flowers , to hear Colombian music and see traditional dances .
# 33629                                                          Adults usually attend language courses , or use a variety of online courses .
# 16994                                                                              The building has two changing rooms , for men and women .
# 26694                                                                    The amount of talking done by the students was more than pleasing .
#
#        correct_char_count  original_char_count  correct_word_count  \
# 21674                  55                   55                  12
# 22820                 133                  122                  25
# 33629                  77                   80                  14
# 16994                  57                   55                  12
# 26694                  67                   67                  13
#
#        original_word_count
# 21674                   12
# 22820                   25
# 33629                   16
# 16994                   11
# 26694                   13

# %% [markdown]
# Check NA

# %%
# prompt: get NA count for all columns

train_df.isna().sum()
# Out:
# original               0
# corrected              0
# correct_char_count     0
# original_char_count    0
# correct_word_count     0
# original_word_count    0
# dtype: int64

# %% [markdown]
# Count total no of sentences where original and corrected column are same

# %%
# prompt: count total no of sentences where original and corrected column are same

same_sentence_count = train_df[train_df['original'] == train_df['corrected']].shape[0]
print(f"Number of sentences where original and corrected are same: {same_sentence_count}")
# Out:
# Number of sentences where original and corrected are same: 11571

# %%
# prompt: count total no of sentences where original and corrected column are not same

initial_df = train_df[train_df['original'] != train_df['corrected']]
print(f"Number of sentences where original and corrected are different: {initial_df.shape[0]}")
# Out:
# Number of sentences where original and corrected are different: 22737

# %%
initial_df.shape
# Out:
# (22737, 6)

# %% [markdown]
# Remove duplicate

# %%
# prompt: Remove duplicate all columns
initial_df.duplicated().sum()
#initial_df_1 = initial_df.drop_duplicates(subset=['original', 'corrected', 'correct_char_count', 'original_char_count', 'correct_word_count', 'original_word_count'], keep='first')
# Out:
# 27

# %%
initial_df[initial_df.duplicated(keep=False)].sort_values('corrected')
# Out:
#                                                                                                                          original  \
# 10055  All in all , using renewable energy and improve our regulation is two ways to cutting down pollution for a better future .
# 10064  All in all , using renewable energy and improve our regulation is two ways to cutting down pollution for a better future .
# 31713                                                                                                       Dear Mrs Kate Ashby ,
# 17447                                                                                                       Dear Mrs Kate Ashby ,
# 9237                                                                                                        Dear Mrs Kate Ashby ,
# 31806                                                                                                                  Dear Sir :
# 13266                                                                                                                  Dear Sir :
# 18334                                                                                                          Dear sir / madam ,
# 28485                                                                                                          Dear sir / madam ,
# 24208                                                                                                                 Sincerely ,
# 21117                                                                                                                 Sincerely ,
# 33039                                                                                                                   I 'm ok .
# 33036                                                                                                                   I 'm ok .
# 7782                                                                                      I look forward to hearing from you soon
# 14789                                                                                     I look forward to hearing from you soon
# 2952                                                                                                    I hope your answer soon .
# 18179                                                                                                   I hope your answer soon .
# 4937                                                    I love this family because it is a single mother and I think it is easier
# 4940                                                    I love this family because it is a single mother and I think it is easier
# 4935                                                                                 yes , I 'm talking with a family in Oxford .
# 4938                                                                                 yes , I 'm talking with a family in Oxford .
# 15137                                                                                                             Yours sincerely
# 31410                                                                                                             Yours sincerely
# 8729                                                                                                              Yours sincerely
# 15729                                                                                                             Yours sincerely
# 23054                                                                                                                 Sincerely ,
# 21391                                                                                                           Yours sincerely ,
# 22096                                                                                                           Sincerely yours ,
# 32135                                                                                                           Sincerely yours ,
# 16412                                                                                                           Sincerely yours ,
# 18520                                                                                                                 Sincerely ,
# 18325                                                                                                                 Sincerely ,
# 17330                                                                                                          Yours faithfully .
# 15616                                                                                                                 Sincerely ,
# 13844                                                                                                           Yours sincerely ,
# 13273                                                                                                          Yours faithfully .
# 12519                                                                                                           Yours sincerely ,
# 10788                                                                                                                 Sincerely ,
# 33950                                                                                                           Yours sincerely ,
# 23129                                                                                                          Yours faithfully ,
# 14188                                                                                                            Your sincerely ,
# 13732                                                                                                          Yours faithfully ,
# 31804                                                                                                          Yours faithfully ,
# 21331                                                                                                            Your sincerely ,
#
#                                                                                                                            corrected  \
# 10055  All in all , using renewable energy and improving our regulations are two ways to cut down on pollution for a better future .
# 10064  All in all , using renewable energy and improving our regulations are two ways to cut down on pollution for a better future .
# 31713                                                                                                               Dear Mrs Ashby ,
# 17447                                                                                                               Dear Mrs Ashby ,
# 9237                                                                                                                Dear Mrs Ashby ,
# 31806                                                                                                                     Dear Sir ,
# 13266                                                                                                                     Dear Sir ,
# 18334                                                                                                             Dear Sir / Madam ,
# 28485                                                                                                             Dear Sir / Madam ,
# 24208                                                                                                                   Faithfully ,
# 21117                                                                                                                   Faithfully ,
# 33039                                                                                                                      I 'm OK .
# 33036                                                                                                                      I 'm OK .
# 7782                                                                                       I look forward to hearing from you soon .
# 14789                                                                                      I look forward to hearing from you soon .
# 2952                                                                                  I look forward to receiving your answer soon .
# 18179                                                                                 I look forward to receiving your answer soon .
# 4937                                                     I love this family because it is a single mother and I think it is easier .
# 4940                                                     I love this family because it is a single mother and I think it is easier .
# 4935                                                                                    Yes , I 'm talking with a family in Oxford .
# 4938                                                                                    Yes , I 'm talking with a family in Oxford .
# 15137                                                                                                               Yours faithfully
# 31410                                                                                                               Yours faithfully
# 8729                                                                                                                Yours faithfully
# 15729                                                                                                               Yours faithfully
# 23054                                                                                                             Yours faithfully ,
# 21391                                                                                                             Yours faithfully ,
# 22096                                                                                                             Yours faithfully ,
# 32135                                                                                                             Yours faithfully ,
# 16412                                                                                                             Yours faithfully ,
# 18520                                                                                                             Yours faithfully ,
# 18325                                                                                                             Yours faithfully ,
# 17330                                                                                                             Yours faithfully ,
# 15616                                                                                                             Yours faithfully ,
# 13844                                                                                                             Yours faithfully ,
# 13273                                                                                                             Yours faithfully ,
# 12519                                                                                                             Yours faithfully ,
# 10788                                                                                                             Yours faithfully ,
# 33950                                                                                                             Yours faithfully ,
# 23129                                                                                                              Yours sincerely ,
# 14188                                                                                                              Yours sincerely ,
# 13732                                                                                                              Yours sincerely ,
# 31804                                                                                                              Yours sincerely ,
# 21331                                                                                                              Yours sincerely ,
#
#        correct_char_count  original_char_count  correct_word_count  \
# 10055                 125                  122                  24
# 10064                 125                  122                  24
# 31713                  16                   21                   4
# 17447                  16                   21                   4
# 9237                   16                   21                   4
# 31806                  10                   10                   3
# 13266                  10                   10                   3
# 18334                  18                   18                   5
# 28485                  18                   18                   5
# 24208                  12                   11                   2
# 21117                  12                   11                   2
# 33039                   9                    9                   4
# 33036                   9                    9                   4
# 7782                   41                   39                   9
# 14789                  41                   39                   9
# 2952                   46                   25                   9
# 18179                  46                   25                   9
# 4937                   75                   73                  17
# 4940                   75                   73                  17
# 4935                   44                   44                  11
# 4938                   44                   44                  11
# 15137                  16                   15                   2
# 31410                  16                   15                   2
# 8729                   16                   15                   2
# 15729                  16                   15                   2
# 23054                  18                   11                   3
# 21391                  18                   17                   3
# 22096                  18                   17                   3
# 32135                  18                   17                   3
# 16412                  18                   17                   3
# 18520                  18                   11                   3
# 18325                  18                   11                   3
# 17330                  18                   18                   3
# 15616                  18                   11                   3
# 13844                  18                   17                   3
# 13273                  18                   18                   3
# 12519                  18                   17                   3
# 10788                  18                   11                   3
# 33950                  18                   17                   3
# 23129                  17                   18                   3
# 14188                  17                   16                   3
# 13732                  17                   18                   3
# 31804                  17                   18                   3
# 21331                  17                   16                   3
#
#        original_word_count
# 10055                   23
# 10064                   23
# 31713                    5
# 17447                    5
# 9237                     5
# 31806                    3
# 13266                    3
# 18334                    5
# 28485                    5
# 24208                    2
# 21117                    2
# 33039                    4
# 33036                    4
# 7782                     8
# 14789                    8
# 2952                     6
# 18179                    6
# 4937                    16
# 4940                    16
# 4935                    11
# 4938                    11
# 15137                    2
# 31410                    2
# 8729                     2
# 15729                    2
# 23054                    2
# 21391                    3
# 22096                    3
# 32135                    3
# 16412                    3
# 18520                    2
# 18325                    2
# 17330                    3
# 15616                    2
# 13844                    3
# 13273                    3
# 12519                    3
# 10788                    2
# 33950                    3
# 23129                    3
# 14188                    3
# 13732                    3
# 31804                    3
# 21331                    3

# %%
initial_df.shape
# Out:
# (22737, 6)

# %%
initial_df = initial_df.drop_duplicates().reset_index(drop=True)

# %%
initial_df[initial_df.duplicated(keep=False)].sort_values('corrected')
# Out:
# Empty DataFrame
# Columns: [original, corrected, correct_char_count, original_char_count, correct_word_count, original_word_count]
# Index: []

# %%
initial_df.shape
# Out:
# (22710, 6)

# %% [markdown]
# Remove Sentences with length = 1

# %%
initial_df[initial_df['original_word_count']<2]
# Out:
#             original         corrected  correct_char_count  \
# 925           kisses            Kisses                   6
# 3003      Faithfully  Yours faithfully                  16
# 4271       fsdjgdofg                                     0
# 4497            toni              Toni                   4
# 4831             lou               Lou                   3
# 4884        victoria          Victoria                   8
# 5156       Sincerely  Yours Faithfully                  16
# 7345           hello             Hello                   5
# 10519             Ou                                     0
# 10747      sincerely  Yours faithfully                  16
# 12873         Thanks          Thanks .                   8
# 13785         Thanks       Thank you .                  11
# 14934           good              Good                   4
# 15505     conclution        Conclusion                  10
# 16091      Sincerely  Yours faithfully                  16
# 16390  Desadvantages     Disadvantages                  13
# 18015              .                                     0
# 18047     Conclusión        Conclusion                  10
#
#        original_char_count  correct_word_count  original_word_count
# 925                      6                   1                    1
# 3003                    10                   2                    1
# 4271                     9                   0                    1
# 4497                     4                   1                    1
# 4831                     3                   1                    1
# 4884                     8                   1                    1
# 5156                     9                   2                    1
# 7345                     5                   1                    1
# 10519                    2                   0                    1
# 10747                    9                   2                    1
# 12873                    6                   2                    1
# 13785                    6                   3                    1
# 14934                    4                   1                    1
# 15505                   10                   1                    1
# 16091                    9                   2                    1
# 16390                   13                   1                    1
# 18015                    1                   0                    1
# 18047                   10                   1                    1

# %%
initial_df[initial_df['correct_word_count']<2]
# Out:
#               original      corrected  correct_char_count  \
# 925             kisses         Kisses                   6
# 1698        cell phone      cellphone                   9
# 2147          good bye        Goodbye                   7
# 4270   yes becouse yes                                  0
# 4271         fsdjgdofg                                  0
# 4497              toni           Toni                   4
# 4830            dear .           Dear                   4
# 4831               lou            Lou                   3
# 4884          victoria       Victoria                   8
# 7345             hello          Hello                   5
# 7471         thought .              .                   1
# 10519               Ou                                  0
# 14934             good           Good                   4
# 15359     The football       Football                   8
# 15505       conclution     Conclusion                  10
# 16390    Desadvantages  Disadvantages                  13
# 16617             Oh !             Oh                   2
# 18015                .                                  0
# 18047       Conclusión     Conclusion                  10
#
#        original_char_count  correct_word_count  original_word_count
# 925                      6                   1                    1
# 1698                    10                   1                    2
# 2147                     8                   1                    2
# 4270                    15                   0                    3
# 4271                     9                   0                    1
# 4497                     4                   1                    1
# 4830                     6                   1                    2
# 4831                     3                   1                    1
# 4884                     8                   1                    1
# 7345                     5                   1                    1
# 7471                     9                   1                    2
# 10519                    2                   0                    1
# 14934                    4                   1                    1
# 15359                   12                   1                    2
# 15505                   10                   1                    1
# 16390                   13                   1                    1
# 16617                    4                   1                    2
# 18015                    1                   0                    1
# 18047                   10                   1                    1

# %%
initial_df[(initial_df['original_word_count']<2) | (initial_df['correct_word_count']<2)].shape
# Out:
# (25, 6)

# %%
final_df = initial_df[(initial_df['original_word_count']>=2) & (initial_df['correct_word_count']>=2)].reset_index(drop=True)
final_df.shape
# Out:
# (22685, 6)

# %%
final_df[final_df['correct_word_count'] <= 30].shape
# Out:
# (18688, 6)

# %%
print('Min correct word count:', final_df['correct_word_count'].min())
print('Max correct word count:', final_df['correct_word_count'].max())
# Out:
# Min correct word count: 2
# Max correct word count: 236

# %%
print('Min correct word count:', final_df['original_word_count'].min())
print('Max correct word count:', final_df['original_word_count'].max())
# Out:
# Min correct word count: 2
# Max correct word count: 220

# %%
final_df.shape
# Out:
# (22685, 6)

# %%
from transformers import BertTokenizer, BertModel

tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# SOS_TOKEN = "[<SOS>]"
# EOS_TOKEN = "[<EOS>]"

# SPECIALS = [SOS_TOKEN, EOS_TOKEN]
# tokenizer.add_special_tokens({'additional_special_tokens': SPECIALS})

encoded_inputs:list[list[int]] = []
encoded_outputs:list[list[int]] = []

for sentence in final_df['original']:
  encoded_inputs.append(tokenizer.encode(sentence))

for sentence in final_df['corrected']:
  encoded_outputs.append(tokenizer.encode(sentence))

with open('/content/drive/MyDrive/CS4248NLP/bert_encoded_train_dataset.csv', mode="w") as file:
  for encoded_input, encoded_output in zip(encoded_inputs, encoded_outputs):
    file.write(" ".join([str(i) for i in encoded_input]))
    file.write(",")
    file.write(" ".join([str(i) for i in encoded_output]))
    file.write("\n")

# %%
tokenizer.save_vocabulary("/content/drive/MyDrive/CS4248NLP/vocab.txt")
# Out:
# ('/content/drive/MyDrive/CS4248NLP/vocab.txt',)

# %%
tokenizer
# Out:
# BertTokenizer(name_or_path='bert-base-cased', vocab_size=28996, model_max_length=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
# tokenizer.convert_tokens_to_ids(['[<SOS>]'])

# %%
# tokenizer.convert_ids_to_tokens([100])

# %% [markdown]
# ## **BERT EDA**

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
input_text = "To be Journalist , I must study very hard so I 'll try to learn in order to make my dream comes true ."
output_text = "To be a journalist , I must study very hard , so I 'll try to learn in order to make my dream come true ."
print("Tokens of input:", tokenizer.tokenize(input_text))
print("Tokens of output:", tokenizer.tokenize(output_text))
encoded_input = tokenizer.encode(input_text)
print("Encoded OHE tensor:", encoded_input)
print("Decoded (Should be same as text):", tokenizer.decode(encoded_input))
# Out:
# Tokens of input: ['To', 'be', 'Journal', '##ist', ',', 'I', 'must', 'study', 'very', 'hard', 'so', 'I', "'", 'll', 'try', 'to', 'learn', 'in', 'order', 'to', 'make', 'my', 'dream', 'comes', 'true', '.']
# Tokens of output: ['To', 'be', 'a', 'journalist', ',', 'I', 'must', 'study', 'very', 'hard', ',', 'so', 'I', "'", 'll', 'try', 'to', 'learn', 'in', 'order', 'to', 'make', 'my', 'dream', 'come', 'true', '.']
# Encoded OHE tensor: [101, 1706, 1129, 3603, 1776, 117, 146, 1538, 2025, 1304, 1662, 1177, 146, 112, 1325, 2222, 1106, 3858, 1107, 1546, 1106, 1294, 1139, 4185, 2502, 2276, 119, 102]
# Decoded (Should be same as text): [CLS] To be Journalist, I must study very hard so I'll try to learn in order to make my dream comes true. [SEP]

# %%
## OOV 1
input_text = preprocess_df['original'][3]
print(input_text)
encoded_input = tokenizer.encode(input_text)
# print("Tokens of input:", tokenizer.tokenize(input_text))
print("Encoded OHE tensor:", encoded_input)
print("Decoded (Should be same as text):", tokenizer.decode(encoded_input))
# Out:
# I recommend visiting the artificial lake in the certer of the city which is surrounded by a park . <EOS>
# Encoded OHE tensor: [101, 146, 18029, 5807, 1103, 8246, 3521, 1107, 1103, 172, 7340, 1200, 1104, 1103, 1331, 1134, 1110, 4405, 1118, 170, 2493, 119, 133, 142, 9025, 135, 102]
# Decoded (Should be same as text): [CLS] I recommend visiting the artificial lake in the certer of the city which is surrounded by a park. < EOS > [SEP]

# %%
## OOV 2
input_text = preprocess_df['original'][3]
print(input_text)
encoded_input = tokenizer.encode(input_text)
print("Tokens of input:", tokenizer.tokenize(input_text))
print("Encoded OHE tensor:", encoded_input)
print("Decoded (Should be same as text):", tokenizer.decode(encoded_input))
# Out:
# I recommend visiting the artificial lake in the certer of the city which is surrounded by a park . <EOS>
# Tokens of input: ['I', 'recommend', 'visiting', 'the', 'artificial', 'lake', 'in', 'the', 'c', '##ert', '##er', 'of', 'the', 'city', 'which', 'is', 'surrounded', 'by', 'a', 'park', '.', '<', 'E', '##OS', '>']
# Encoded OHE tensor: [101, 146, 18029, 5807, 1103, 8246, 3521, 1107, 1103, 172, 7340, 1200, 1104, 1103, 1331, 1134, 1110, 4405, 1118, 170, 2493, 119, 133, 142, 9025, 135, 102]
# Decoded (Should be same as text): [CLS] I recommend visiting the artificial lake in the certer of the city which is surrounded by a park. < EOS > [SEP]

# %%
tokenizer.convert_ids_to_tokens([100])
# Out:
# ['[UNK]']

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
SOS_TOKEN = "[<SOS>]"
EOS_TOKEN = "[<EOS>]"

SPECIALS = [SOS_TOKEN, EOS_TOKEN]
tokenizer.add_special_tokens({'additional_special_tokens': SPECIALS})


encoded_inputs:list[list[int]] = []
encoded_outputs:list[list[int]] = []
for sentence in preprocess_df['original']:
  encoded_inputs.append(tokenizer.encode(sentence))
for sentence in preprocess_df['corrected']:
  encoded_outputs.append(tokenizer.encode(sentence))
with open('/content/drive/MyDrive/CS4248NLP/bert_encoded_train_dataset.csv', mode="w") as file:
  for encoded_input, encoded_output in zip(encoded_inputs, encoded_outputs):
    file.write(" ".join([str(i) for i in encoded_input]))
    file.write(",")
    file.write(" ".join([str(i) for i in encoded_output]))
    file.write("\n")

# %% [markdown]
# ## **Save Vocab**

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
tokenizer.save_vocabulary("/content/drive/MyDrive/CS4248NLP/vocab.txt")
# Out:
# ('/content/drive/MyDrive/CS4248NLP/vocab.txt',)

# %%
tokenizer.vocab_size
# Out:
# 28996
